# %%
def load_csv(filename):
    with open(filename, 'r', encoding='utf-8-sig') as f:
        csv_list = [row.strip().split(',') for row in f.readlines()]
    return csv_list

def printx(listx):
    for x in listx:
        print(x)

# %%
def parse_row(row):
    name = row[0].lower()
    prevElemCombos = row[1].lower().split(' / ')
    prevElemCombos = [p.lower().split('+') for p in prevElemCombos]
    if prevElemCombos == [['available from start.']]:
        prevElemCombos = [['BASE_ELEMENT']]
    prevElemCombos.sort()
    for p in prevElemCombos:
        p.sort()
    return [prevElemCombo + [name] for prevElemCombo in prevElemCombos]

def parse_rows(csv_list):
    r = []
    for row in csv_list:
        r.extend(parse_row(row))
    return r

# %%
elemsFilename = 'elements_data.csv'
csv_list = load_csv(elemsFilename)

# %%
import pandas as pd
from tqdm import tqdm

def create_elements_df(csv_list):
    r = parse_rows(csv_list)
    df = pd.DataFrame(r, columns=['elem1','elem2', 'result'])
    base_elements = get_base_elements(csv_list)
    return df[~df.index.isin(base_elements.index)]


def get_base_elements(csv_list):
    df = pd.DataFrame(parse_rows(csv_list), columns=['elem1','elem2', 'result'])
    return df[df['elem1']=='BASE_ELEMENT']

def get_elements_list(dfs):
    r = []
    for col in list(dfs.columns):
        r.extend(dfs[col].tolist())
    return list(set(r))

# %%
dfs = create_elements_df(csv_list)
dfs.head()
# Out:
#    elem1  elem2       result
# 0   rain   smog    acid rain
# 1   rain  smoke    acid rain
# 3   bird  metal     airplane
# 4   bird  steel     airplane
# 5  clock  sound  alarm clock

# %%
base_elements = get_base_elements(csv_list)['elem2'].tolist()
print(base_elements)
# Out:
# ['air', 'earth', 'fire', 'water']

# %%
def get_unique_current_combos(curr_elements, dfs):
    possible_combos = [[elem1, elem2] for elem1 in curr_elements for elem2 in curr_elements if elem1 != elem2]
    for i in range(len(possible_combos)):
        possible_combos[i].sort()
        possible_combos[i] = '+'.join(possible_combos[i])
    possible_combos = list(set(possible_combos))
    possible_combos = [p.split('+') for p in possible_combos]
    return possible_combos

def get_elem_score(elem, dfs, levels=0):
    dFilter = (dfs['elem1']==elem) | (dfs['elem2']==elem)
    if levels == 0:
        return sum(dFilter)
    else:
        next_possible_elements = dfs.loc[dFilter, 'result'].tolist()
        return sum([get_elem_score(e, dfs, levels-1) for e in next_possible_elements])

def get_next_possible_combos(curr_elements, dfs):
    r = []
    unique_combos = get_unique_current_combos(curr_elements, dfs)
    for combo in unique_combos:
        l = (dfs['elem1']==combo[0]) & (dfs['elem2']==combo[1])
        if l.any():
            r.append([dfs.loc[l, 'elem1'].tolist()[0], dfs.loc[l, 'elem2'].tolist()[0] , dfs.loc[l, 'result'].tolist()[0]])
    return [x for x in r if x[-1] not in curr_elements]

def get_next_possible_elements(curr_elements, dfs):
    r = get_next_possible_combos(curr_elements, dfs)
    return [x[-1] for x in r]

# %%
def get_next_best_move(curr_elements, dfs, levels=0):
    next_possible_combos = get_next_possible_combos(curr_elements, dfs)
    scores = [get_elem_score(e[-1], dfs, levels) for e in next_possible_combos]
    return next_possible_combos[scores.index(max(scores))]

def fullCombo_to_string(combo):
    return ' + '.join(combo[:-1]) + ' = ' + combo[-1]

# %%
def get_n_moves(curr_elements, dfs, levels=0, n=10, print_moves=False):
    curr_elements = list(curr_elements)
    r = []
    for i in (range(n) if print_moves else tqdm(range(n))):
        newCombo = get_next_best_move(curr_elements, dfs, levels=levels)
        r.append(fullCombo_to_string(newCombo))
        if print_moves:
            print(i+1, fullCombo_to_string(newCombo))
        curr_elements.append(newCombo[-1])
        curr_elements.sort()
    return r

# %% [markdown]
# # **Complete example**

# %%
elemsFilename = 'elements_data.csv'
csv_list = load_csv(elemsFilename)

dfs = create_elements_df(csv_list)
base_elements = get_base_elements(csv_list)['elem2'].tolist()
nx = 50
x = get_n_moves(curr_elements=base_elements, dfs=dfs, levels=0, n=nx, print_moves=True)
# Out:
# 1 air + fire = energy
# 2 air + energy = wind
# 3 air + water = rain
# 4 earth + rain = plant
# 5 earth + plant = grass
# 6 earth + fire = lava
# 7 air + lava = stone
# 8 fire + stone = metal
# 9 energy + metal = electricity
# 10 air + stone = sand
# 11 fire + sand = glass
# 12 metal + stone = blade
# 13 glass + metal = glasses
# 14 blade + metal = sword
# 15 electricity + metal = wire
# 16 earth + water = mud
# 17 mud + sand = clay
# 18 energy + water = steam
# 19 air + steam = cloud
# 20 air + cloud = sky
# 21 fire + sky = sun
# 22 rain + sun = rainbow
# 23 sky + stone = moon
# 24 moon + sky = night
# 25 night + sky = star
# 26 grass + sun = hay
# 27 star + sun = space
# 28 night + plant = carbon dioxide
# 29 metal + rainbow = gold
# 30 mud + plant = swamp
# 31 energy + swamp = life
# 32 earth + life = human
# 33 air + life = bird
# 34 human + metal = tool
# 35 life + stone = egg
# 36 bird + metal = airplane
# 37 human + plant = farmer
# 38 farmer + life = livestock
# 39 hay + livestock = horse
# 40 grass + livestock = cow
# 41 cow + farmer = milk
# 42 livestock + mud = pig
# 43 blade + livestock = meat
# 44 human + rain = cold
# 45 cold + steam = snow
# 46 cold + water = ice
# 47 earth + tool = field
# 48 egg + swamp = lizard
# 49 carbon dioxide + plant = oxygen
# 50 electricity + glass = light bulb

# %%
x = get_n_moves(curr_elements=base_elements, dfs=dfs, levels=1, n=255, print_moves=True)
# Out:
# 1 air + fire = energy
# 2 air + water = rain
# 3 earth + rain = plant
# 4 earth + plant = grass
# 5 air + energy = wind
# 6 earth + water = mud
# 7 energy + water = steam
# 8 air + steam = cloud
# 9 air + cloud = sky
# 10 fire + sky = sun
# 11 grass + mud = swamp
# 12 energy + swamp = life
# 13 earth + life = human
# 14 human + plant = farmer
# 15 farmer + life = livestock
# 16 air + life = bird
# 17 grass + livestock = cow
# 18 human + rain = cold
# 19 earth + fire = lava
# 20 air + lava = stone
# 21 fire + stone = metal
# 22 human + metal = tool
# 23 air + stone = sand
# 24 life + stone = egg
# 25 energy + metal = electricity
# 26 fire + sand = glass
# 27 metal + stone = blade
# 28 sun + tool = solar cell
# 29 sky + stone = moon
# 30 moon + sky = night
# 31 night + sky = star
# 32 egg + swamp = lizard
# 33 farmer + grass = hay
# 34 earth + tool = field
# 35 livestock + mud = pig
# 36 mud + sand = clay
# 37 cold + steam = snow
# 38 grass + plant = garden
# 39 cow + farmer = milk
# 40 egg + water = hard roe
# 41 egg + sand = turtle
# 42 electricity + glass = light bulb
# 43 electricity + light bulb = light
# 44 farmer + field = wheat
# 45 stone + wheat = flour
# 46 garden + plant = flower
# 47 light + rain = rainbow
# 48 flour + water = dough
# 49 earth + energy = earthquake
# 50 earth + earthquake = mountain
# 51 moon + star = space
# 52 dough + fire = bread
# 53 cloud + livestock = sheep
# 54 glass + sky = telescope
# 55 night + sun = day
# 56 clay + sun = brick
# 57 blade + metal = sword
# 58 hay + tool = pitchfork
# 59 light + tool = flashlight
# 60 metal + steam = boiler
# 61 blade + grass = scythe
# 62 cold + water = ice
# 63 human + snow = snowball
# 64 mountain + rain = river
# 65 metal + rainbow = gold
# 66 hay + livestock = horse
# 67 electricity + metal = wire
# 68 life + swamp = bacteria
# 69 bacteria + human = sickness
# 70 livestock + mountain = goat
# 71 plant + sand = cactus
# 72 cactus + sand = desert
# 73 human + scythe = grim reaper
# 74 grim reaper + human = corpse
# 75 metal + tool = armor
# 76 armor + human = knight
# 77 flower + sun = sunflower
# 78 sheep + tool = wool
# 79 boiler + tool = steam engine
# 80 bird + metal = airplane
# 81 cloud + plant = cotton
# 82 cotton + tool = thread
# 83 garden + water = pond
# 84 blade + livestock = meat
# 85 human + meat = butcher
# 86 energy + sword = lightsaber
# 87 glass + metal = glasses
# 88 glasses + human = nerd
# 89 energy + human = wizard
# 90 night + plant = carbon dioxide
# 91 carbon dioxide + plant = oxygen
# 92 fire + mountain = volcano
# 93 air + earth = dust
# 94 dust + fire = gunpowder
# 95 gunpowder + metal = bullet
# 96 bullet + metal = gun
# 97 thread + tool = fabric
# 98 electricity + nerd = computer
# 99 fire + pig = bacon
# 100 stone + sword = excalibur
# 101 blade + human = blood
# 102 blood + human = vampire
# 103 corpse + earth = grave
# 104 cloud + earth = fog
# 105 airplane + water = seaplane
# 106 pond + water = lake
# 107 excalibur + human = monarch
# 108 gold + monarch = crown
# 109 bread + human = baker
# 110 energy + volcano = ash
# 111 desert + snow = antarctica
# 112 airplane + space = rocket
# 113 fire + human = fireman
# 114 bird + water = duck
# 115 duck + egg = duckling
# 116 grave + stone = gravestone
# 117 human + tool = engineer
# 118 blade + star = shuriken
# 119 fire + plant = tobacco
# 120 bacon + bread = sandwich
# 121 fire + gunpowder = explosion
# 122 fire + lizard = dragon
# 123 engineer + glasses = safety glasses
# 124 meat + sun = jerky
# 125 fog + grass = dew
# 126 bird + ice = penguin
# 127 computer + wire = internet
# 128 bird + human = angel
# 129 mountain + river = waterfall
# 130 antarctica + sky = aurora
# 131 rain + tool = umbrella
# 132 carbon dioxide + fire = fire extinguisher
# 133 plant + sickness = herb
# 134 cotton + fabric = pillow
# 135 human + moon = astronaut
# 136 glass + plant = greenhouse
# 137 bacteria + glasses = microscope
# 138 glass + sand = hourglass
# 139 human + lightsaber = jedi
# 140 wire + wool = steel wool
# 141 bird + flower = hummingbird
# 142 explosion + stone = pop rocks
# 143 carbon dioxide + ice = dry ice
# 144 fire + gun = flamethrower
# 145 ice + rain = hail
# 146 electricity + scythe = lawn mower
# 147 airplane + blade = helicopter
# 148 air + metal = rust
# 149 rainbow + water = paint
# 150 glass + wizard = crystal ball
# 151 electricity + oxygen = ozone
# 152 garden + human = gardener
# 153 goat + human = faun
# 154 gunpowder + wire = dynamite
# 155 snow + wind = blizzard
# 156 tool + wool = sweater
# 157 flower + pond = water lilly
# 158 light bulb + nerd = idea
# 159 bird + horse = pegasus
# 160 horse + human = centaur
# 161 desert + water = oasis
# 162 bird + fire = phoenix
# 163 plant + stone = moss
# 164 explosion + sky = fireworks
# 165 stone + tool = statue
# 166 ice + sun = puddle
# 167 bird + earth = ostrich
# 168 light bulb + metal = lamp
# 169 lamp + lava = lava lamp
# 170 human + sword = warrior
# 171 gun + sword = bayonet
# 172 hay + metal = needle
# 173 milk + wheat = cereal
# 174 flower + steam = perfume
# 175 fire + jedi = darth vader
# 176 crystal ball + snow = snow globe
# 177 egg + hay = nest
# 178 explosion + star = super nova
# 179 jedi + swamp = yoda
# 180 armor + bullet = bulletproof vest
# 181 glasses + water = swim goggles
# 182 desert + wind = dune
# 183 statue + water = fountain
# 184 lizard + rainbow = chameleon
# 185 egg + flour = pasta
# 186 pasta + thread = spaghetti
# 187 gun + water = water gun
# 188 electricity + gun = taser
# 189 human + shuriken = ninja
# 190 earth + sky = horizon
# 191 glass + rainbow = prism
# 192 bacteria + milk = yogurt
# 193 cold + yogurt = frozen yogurt
# 194 mountain + sheep = alpaca
# 195 corpse + life = zombie
# 196 airplane + astronaut = spaceship
# 197 cloud + electricity = storm
# 198 human + wire = electrician
# 199 electricity + zombie = frankenstein
# 200 bird + livestock = chicken
# 201 dough + life = gingerbread man
# 202 blade + electricity = blender
# 203 cold + electricity = fridge
# 204 light + wire = optical fiber
# 205 bird + wizard = owl
# 206 ice + milk = ice cream
# 207 ice cream + milk = milk shake
# 208 engineer + mountain = tunnel
# 209 explosion + metal = grenade
# 210 carbon dioxide + water = soda
# 211 bread + meat = hamburger
# 212 desert + horse = camel
# 213 plant + water = algae
# 214 hard roe + human = caviar
# 215 life + water = plankton
# 216 energy + snow = avalanche
# 217 earth + space = planet
# 218 planet + sun = solar system
# 219 ninja + turtle = ninja turtle
# 220 sand + stone = sandstone
# 221 energy + wind = hurricane
# 222 bird + mountain = eagle
# 223 life + rainbow = unicorn
# 224 sand + swamp = quicksand
# 225 cow + mountain = yak
# 226 life + metal = robot
# 227 human + robot = cyborg
# 228 day + night = twilight
# 229 glasses + sun = sunglasses
# 230 desert + grave = pyramid
# 231 bird + rainbow = peacock
# 232 grass + sandwich = picnic
# 233 bread + fire = toast
# 234 planet + rust = mars
# 235 blood + fabric = bandage
# 236 clay + tool = pottery
# 237 plant + pottery = vase
# 238 pig + pottery = piggy bank
# 239 dragon + knight = hero
# 240 garden + statue = gnome
# 241 bird + statue = pigeon
# 242 energy + milk = butter
# 243 corpse + pyramid = mummy
# 244 egg + fire = omelette
# 245 horse + water = hippo
# 246 earth + steam = geyser
# 247 moon + sun = eclipse
# 248 human + swim goggles = swimmer
# 249 human + seaplane = pilot
# 250 fabric + pilot = parachute
# 251 glass + water = aquarium
# 252 needle + robot = sewing machine
# 253 lizard + swamp = alligator
# 254 flour + milk = batter
# 255 steam engine + water = steamboat

# %%
x = get_n_moves(curr_elements=base_elements, dfs=dfs, levels=2, n=nx, print_moves=True)
# Out:
# 1 air + fire = energy
# 2 air + water = rain
# 3 earth + rain = plant
# 4 earth + plant = grass
# 5 earth + fire = lava
# 6 air + lava = stone
# 7 fire + stone = metal
# 8 air + stone = sand
# 9 fire + sand = glass
# 10 energy + metal = electricity
# 11 earth + water = mud
# 12 grass + mud = swamp
# 13 energy + swamp = life
# 14 earth + life = human
# 15 human + metal = tool
# 16 human + plant = farmer
# 17 life + stone = egg
# 18 air + life = bird
# 19 egg + swamp = lizard
# 20 air + energy = wind
# 21 farmer + life = livestock
# 22 egg + sand = turtle
# 23 earth + tool = field
# 24 energy + water = steam
# 25 air + steam = cloud
# 26 air + cloud = sky
# 27 fire + sky = sun
# 28 sun + tool = solar cell
# 29 sky + stone = moon
# 30 moon + sky = night
# 31 metal + stone = blade
# 32 night + sky = star
# 33 sky + sun = day
# 34 mud + sun = brick
# 35 electricity + glass = light bulb
# 36 electricity + light bulb = light
# 37 grass + livestock = cow
# 38 farmer + field = wheat
# 39 light + tool = flashlight
# 40 blade + grass = scythe
# 41 earth + energy = earthquake
# 42 earth + earthquake = mountain
# 43 grass + scythe = hay
# 44 hay + tool = pitchfork
# 45 human + rain = cold
# 46 cold + steam = snow
# 47 glass + sky = telescope
# 48 blade + metal = sword
# 49 blade + livestock = meat
# 50 glass + metal = glasses

# %% [markdown]
# ----------------------------------------
